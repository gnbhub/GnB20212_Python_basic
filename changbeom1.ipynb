# %% [markdown]
# <a href="https://colab.research.google.com/github/gnbhub/GnB20212_Python_basic/blob/master/changbeom1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.3.5

# %%
data1 = ['a','b','c','d','e']
print(data1)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
sr1 = pd.Series(data1)
print("자료형:",type(sr1))
# Out:
# 자료형: <class 'pandas.core.series.Series'>

# %%
print(sr1)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
data2 = (1,2,3.14, 100, -10)
sr2 = pd.Series(data2)
print(sr2)
sr1.loc[0]
# Out:
# 0      1.00
# 1      2.00
# 2      3.14
# 3    100.00
# 4    -10.00
# dtype: float64
# 'a'

# %%
dict_data = {'c0':sr1, 'c1': sr2}
df1 = pd.DataFrame(dict_data)
df1
# Out:
#   c0      c1
# 0  a    1.00
# 1  b    2.00
# 2  c    3.14
# 3  d  100.00
# 4  e  -10.00
